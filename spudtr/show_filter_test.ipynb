# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import spudtr.filters as filters

# ---lowpass test
ftype = "lowpass"
cutoff_hz = 4.5
sfreq = 250
filters.show_filter(cutoff_hz, sfreq, ftype);
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=True) 
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=False)
# Out:
#  lowpass filter
#  sample rate, fs=250
#  cutoff_hz = 4.5
#  width of transition, width=2 hz
#  ripple_db=53
#  FIR filter size: numtaps = 395, time = 1.58 s, delay = 197 , delay_time = 0.79 s
#  Filter length=395 distorts the first and last 0.7880  seconds of each epoch (= 197 samples at 250 samples / s)

# %%
#---bandpass test
ftype = "bandpass"
cutoff_hz = [3.5, 7.5]
sfreq = 250

filters.show_filter(cutoff_hz, sfreq, ftype);
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=True); 
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=False);
# Out:
#  bandpass filter
#  sample rate, fs=250
#  cutoff_hz = [3.5, 7.5]
#  width of transition, width=2.0 hz
#  ripple_db=53
#  FIR filter size: numtaps = 395, time = 1.58 s, delay = 197 , delay_time = 0.79 s
#  Filter length=395 distorts the first and last 0.7880  seconds of each epoch (= 197 samples at 250 samples / s)

# %%
#---bandstop test
ftype = "bandstop"
cutoff_hz = [3.5, 7.5] 
sfreq = 250

filters.show_filter(cutoff_hz, sfreq, ftype);
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=True); 
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=False);
# Out:
#  bandstop filter
#  sample rate, fs=250
#  cutoff_hz = [3.5, 7.5]
#  width of transition, width=2.0 hz
#  ripple_db=53
#  FIR filter size: numtaps = 395, time = 1.58 s, delay = 197 , delay_time = 0.79 s
#  Filter length=395 distorts the first and last 0.7880  seconds of each epoch (= 197 samples at 250 samples / s)

# %%
#---highpass test
ftype = "highpass"
cutoff_hz = 6.5
sfreq = 250

filters.show_filter(cutoff_hz, sfreq, ftype);
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=True); 
#filters.show_filter(cutoff_hz, sfreq, ftype, sample_effect=False);
# Out:
#  highpass filter
#  sample rate, fs=250
#  cutoff_hz = 6.5
#  width of transition, width=2.0 hz
#  ripple_db=53
#  FIR filter size: numtaps = 395, time = 1.58 s, delay = 197 , delay_time = 0.79 s
#  Filter length=395 distorts the first and last 0.7880  seconds of each epoch (= 197 samples at 250 samples / s)
